# %%
# !pip install ultralytics kaggle -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 932.6/932.6 kB 37.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 41.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 29.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.1 MB/s eta 0:00:00

# %%
from google.colab import files
files.upload()  # Upload kaggle.json
# Out:
#      <input type="file" id="files-e87af48c-3d7e-480f-8a76-4b5eb24893b9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e87af48c-3d7e-480f-8a76-4b5eb24893b9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# Download and unzip dataset
# !kaggle datasets download -d abbasszahreddine2/aerial-vehicle-detection-dataset-yolo-8
# !unzip aerial-vehicle-detection-dataset-yolo-8.zip -d /content/dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/Customized Dataset YOLO 8 (3 Classes)/labels/train/58378.txt
#   inflating: /content/dataset/Customized Dataset YOLO 8 (3 Classes)/labels/train/58380.txt
#   inflating: /content/dataset/Customized Dataset YOLO 8 (3 Classes)/labels/train/58382.txt
#   inflating: /content/dataset/Customized Dataset YOLO 8 (3 Classes)/labels/train/58386.txt
#   inflating: /content/dataset/Customized Dataset YOLO 8 (3 Classes)/labels/train/58390.txt
#   inflating: /content/dataset/Customized Dataset YOLO 8 (3 Classes)/labels/train/58394.txt
#   inflating: /content/dataset/Customized Dataset YOLO 8 (3 Classes)/labels/train/58398.txt
#   inflating: /content/dataset/Customized Dataset YOLO 8 (3 Classes)/labels/train/58401.txt
#   inflating: /content/dataset/Customized Dataset YOLO 8 (3 Classes)/labels/train/58405.txt
#   inflating: /content/dataset/Customized Dataset YOLO 8 (3 Classes)/labels/train/58407.txt
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO("yolov8l.pt")

# Train the model
model.train(data="/content/dataset/Customized Dataset YOLO 8 (3 Classes)/Custom_Dataset.yaml",
            epochs=20,
            imgsz=640,
            batch=10,
            project="/content/dataset/Custom_Dataset_Training",
            name="yolo8l_custom")

# Save everything to Google Drive
# !cp -r /content/dataset/Custom_Dataset_Training /content/drive/MyDrive/Custom_Dataset_Training
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 83.7M/83.7M [00:01<00:00, 63.8MB/s]
# Ultralytics 8.3.89 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# ...
